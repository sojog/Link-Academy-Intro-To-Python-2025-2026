# %%
for i in range(10):
    print("i=", i)
# Out:
# i= 0
# i= 1
# i= 2
# i= 3
# i= 4
# i= 5
# i= 6
# i= 7
# i= 8
# i= 9

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
for i in range(4, 10):
    print("i=", i)
# Out:
# i= 4
# i= 5
# i= 6
# i= 7
# i= 8
# i= 9

# %%
list(range(4, 10))
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
for i in range(4, 10):
    print("i=", i, type(i))
# Out:
# i= 4 <class 'int'>
# i= 5 <class 'int'>
# i= 6 <class 'int'>
# i= 7 <class 'int'>
# i= 8 <class 'int'>
# i= 9 <class 'int'>

# %%
for i in range(5, 11):
    print("i=", i, type(i))
# Out:
# i= 5 <class 'int'>
# i= 6 <class 'int'>
# i= 7 <class 'int'>
# i= 8 <class 'int'>
# i= 9 <class 'int'>
# i= 10 <class 'int'>

# %%
for i in range(4, 10):
    print("i=", i + 1, type(i))
# Out:
# i= 5 <class 'int'>
# i= 6 <class 'int'>
# i= 7 <class 'int'>
# i= 8 <class 'int'>
# i= 9 <class 'int'>
# i= 10 <class 'int'>

# %%
for i in range(4):
    print("Python")
# Out:
# Python
# Python
# Python
# Python
