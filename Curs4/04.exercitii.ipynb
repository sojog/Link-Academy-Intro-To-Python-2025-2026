# %%
print(not (True and False) or (not True and False))
# Out:
# True

# %%
print(not (False) or (not True and False))
# Out:
# True

# %%
print(not (False) or (False and False))
# Out:
# True

# %%
print(not (False) or (False))
# Out:
# True

# %%
print(True or (False))
# Out:
# True

# %%
print(True or False)
# Out:
# True

# %% [markdown]
# ## OR. - cel putin 1 sa fie adevarata (True) ca rezultatul sa fie adevarat

# %%
print(True or True)
print(True or False)
# Out:
# True
# True

# %%
print(False and False)
print(False and True)
# Out:
# False
# False

# %%
A = True
B = False 
print(not (A or B) == (not A and not B))
# Out:
# True

# %%
A = True
B = False 
print(not (True) == (not A and not B))
# Out:
# True

# %%
A = True
B = False 
print(not (True) == (False and True))
# Out:
# True

# %%
A = True
B = False 
print(not (True) == (False and True))
# Out:
# True

# %%
A = True
B = False 
print(not (True) == (False))
# Out:
# True

# %%
A = True
B = False 
print(False == (False))
# Out:
# True

# %%
A = True
B = False 
print(False == False)
# Out:
# True

# %% [markdown]
# # Operatii scurte (short-hand)

# %%
x = 20

print(x + 2)
# Out:
# 22

# %%
print(x)
# Out:
# 20

# %%
x = x + 3
print(x)
# Out:
# 23

# %%
x += 5
print(x)
# Out:
# 28

# %%
x -= 5
print(x)
# Out:
# 23

# %%
x *= 2
print(x)
# Out:
# 46

# %%
x %= 3
print(x)
# Out:
# 1

# %% [markdown]
# # Operator de comparatie

# %%
x != 2
# Out:
# True

# %% [markdown]
# # Operator de comparatie

# %%
x == 2
# Out:
# False
