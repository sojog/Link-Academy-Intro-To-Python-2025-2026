# %%
parola = " Python"
parola_confirmata = "Python"
print(parola==parola_confirmata)
# Out:
# False

# %%
parola = " Python"
parola.capitalize()
# Out:
# ' python'

# %%
parola = " Python"
parola.upper()
# Out:
# ' PYTHON'

# %%
parola = " Python"
parola.lower()
# Out:
# ' python'

# %%
parola = " Python"
parola.isnumeric()
# Out:
# False

# %%
parola = "312421"
parola.isnumeric()
# Out:
# True

# %%
parola = "312421"
parola.isdecimal()
# Out:
# True

# %%
parola = "312421"
parola.split()
# Out:
# ['312421']

# %%
parola = "31 24 21"
parola.split()
# Out:
# ['31', '24', '21']

# %%
parola = "  31 24 21.  "
parola.split()
# Out:
# ['31', '24', '21.']

# %%
parola = "  31 24 21.  "
parola.strip()
# Out:
# '31 24 21.'
