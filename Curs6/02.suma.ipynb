# %%
lista = [22, 33, 44, 55]

suma = 0

for i in lista:
    print("i=", i)
    suma = suma + i
print("suma = ", suma)
# Out:
# i= 22
# i= 33
# i= 44
# i= 55
# suma =  154

# %%
print(variabila)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(variabila)
#
# NameError: name 'variabila' is not defined
