# %%
10 // 5
# Out:
# 2

# %%
10 / 5
# Out:
# 2.0

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
round(10 / 3)
# Out:
# 3

# %%
round(312.5747487238472837)
# Out:
# 313

# %%
round(312.4747487238472837)
# Out:
# 312

# %%
round(312.4747487238472837, 2)
# Out:
# 312.47

# %%
round(312.4747487238472837, 3)
# Out:
# 312.475

# %%
x_1 = 20
x_2 = 30 
round(x_1 / x_2, 3)
# Out:
# 0.667
