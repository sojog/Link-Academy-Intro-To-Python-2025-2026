# %%
x = None
print(x, type(x))
# Out:
# None <class 'NoneType'>

# %%
x + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x + 1
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
bool(None)
# Out:
# False

# %%
print("Buna seara")
# Out:
# Buna seara

# %%
rezultat = print("Buna seara")
print(rezultat)
# Out:
# Buna seara
# None

# %%
print(rezultat,  type(rezultat))
# Out:
# None <class 'NoneType'>

# %%
input(None)
# Out:
# '312'
