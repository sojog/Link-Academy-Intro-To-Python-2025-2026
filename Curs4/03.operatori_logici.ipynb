# %%
True and True
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print(True  or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(10  or True)
# Out:
# 10

# %%
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(10.321)
# Out:
# True

# %%
bool(0.0)
# Out:
# False
