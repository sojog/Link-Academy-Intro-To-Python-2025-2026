# %%
if False:
    print("Real")
elif True:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Milan

# %%
if True:
    print("Real")
elif True:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real

# %%
if 321 > 12 :
    print("Real")
elif True:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real

# %%
if "hello":
    print("Real")
elif True:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real

# %%
if bool("hello"):
    print("Real")
elif True:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real

# %%
if 321 < 12 :
    print("Real")
elif False:
    print("Milan")
elif True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Liverpool

# %%
if 321 > 12 :
    print("Real")
elif False:
    print("Milan")
elif False:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real

# %%
if False:
    print("Real")


if True:
    print("Milan")

    
if True:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Milan
# Liverpool

# %%
if True:
    print("Real")
if True:
    print("Milan")
if False:
    print("Liverpool")
else:
    print("Bayern")
# Out:
# Real
# Milan
# Bayern

# %%
if True:
    print("Real")

if True:
    print("Milan")
else:
    print("Bayern")

if False:
    print("Liverpool")
# Out:
# Real
# Milan

# %%
if True:
    print("Real")
elif True:
    print("Milan")
else:
    print("Bayern")
    
if False:
    print("Liverpool")
# Out:
# Real

# %%
if 1:
    print("always")
else:
    print("never")
# Out:
# always

# %%
if 0:
    print("always")
else:
    print("never")
# Out:
# never

# %%
if 1 > 0:
    print("always")
else:
    print("never")
# Out:
# always

# %%
if 1:
    print("always")
else:
    print("never")
# Out:
# always

# %%
if bool(1):
    print("always")
else:
    print("never")
# Out:
# always

# %%
if True:
    print("always")
else:
    print("never")
# Out:
# always

# %%
if -321:
    print("always")
else:
    print("never")
# Out:
# always

# %%
if 320-321+1:
    print("always")
else:
    print("never")
# Out:
# never

# %%
if 30 % 10 :
    print("always")
else:
    print("never")
# Out:
# never

# %%
30 % 10
# Out:
# 0

# %%
30 // 10
# Out:
# 3

# %%
if [] :
    print("always")
else:
    print("never")
# Out:
# never

# %%
a = [ ]  
print(a, type(a))
# Out:
# [] <class 'list'>

# %%
if [321] :
    print("always")
else:
    print("never")
# Out:
# always

# %%
if [''] :
    print("always")
else:
    print("never")
# Out:
# always

# %%
if [0] :
    print("always")
else:
    print("never")
# Out:
# always

# %%
if bool([321]) :
    print("always")
else:
    print("never")
# Out:
# always

# %%
if None:
    print("always")
else:
    print("never")
# Out:
# never

# %%
x = not None
if x:
    print("always")
else:
    print("never")
# Out:
# always

# %%
x = not not None
if x:
    print("always")
else:
    print("never")
print("x=", x)
# Out:
# never
# x= False

# %%
x = [123, 20]
x.pop()
x.pop()

if x:
    print("always")
else:
    print("never")

print(x)
# Out:
# never
# []

# %%
x = [123]
x.pop()
x.append(12)


if x:
    print("always")
else:
    print("never")

print(x)
# Out:
# always
# [12]

# %%
a = 1,
print(type(a))
# Out:
# <class 'tuple'>

# %%
a = [2, 3, 3, 51, 3]
print(a, type(a))
# Out:
# [2, 3, 3, 51, 3] <class 'list'>

# %%
a = (2, 3, 3, 51, 3)
print(a, type(a))
# Out:
# (2, 3, 3, 51, 3) <class 'tuple'>

# %% [markdown]
# ## Tuple si List sunt colectii ordonate (secvente)
# ## Functioneaza identic la nivel de citire a elementelor

# %%
a_list = [2, 3, 3, 51, 3]
print(a_list, type(a_list))
print("len", len(a_list))
for i in a_list:
    print("i=", i)

print("primul=", a_list[0])
# Out:
# [2, 3, 3, 51, 3] <class 'list'>
# len 5
# i= 2
# i= 3
# i= 3
# i= 51
# i= 3
# primul= 2

# %%
a_tuple = (2, 3, 3, 51, 3)
print(a_tuple, type(a_tuple))
print("len", len(a_tuple))
for i in a_tuple:
    print("i=", i)


print("primul=", a_tuple[0])
# Out:
# (2, 3, 3, 51, 3) <class 'tuple'>
# len 5
# i= 2
# i= 3
# i= 3
# i= 51
# i= 3
# primul= 2

# %% [markdown]
# ## Tuple este imutabil

# %%
a_list = [2, 3, 3, 51, 3]
a_list.append(31312)
a_list
# Out:
# [2, 3, 3, 51, 3, 31312]

# %%
a_tuple = (2, 3, 3, 51, 3)
a_tuple.append(21242)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 a_tuple = (2, 3, 3, 51, 3)
# ----> 2 a_tuple.append(21242)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a_tuple = (2, 3, 3, 51, 3)
a_tuple.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 2
#       1 a_tuple = (2, 3, 3, 51, 3)
# ----> 2 a_tuple.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
a_tuple[0]
# Out:
# 2

# %%
a_tuple[0] = 231
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 a_tuple[0] = 231
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Tuplul foloseste paranteze rotunde

# %%
1 + 2 * 3
# Out:
# 7

# %%
(1 + 2) * 3
# Out:
# 9

# %%
x = (321, 4162, 523, 410)
type(x), x
# Out:
# (tuple, (321, 4162, 523, 410))

# %%
x = (321, 4162, 523, 410)
print(type(x), x)
# Out:
# <class 'tuple'> (321, 4162, 523, 410)

# %%
x = 321, 4162, 523, 41
print(type(x), x)
# Out:
# <class 'tuple'> (321, 4162, 523, 41)

# %%
x = (321, 4162, 523, 41)
print(type(x), x)
print(len(x))
# Out:
# <class 'tuple'> (321, 4162, 523, 41)
# 4

# %%
x = ()
print(type(x), x)
print(len(x))
# Out:
# <class 'tuple'> ()
# 0

# %%
x = (321, 4162)
print(type(x), x)
print(len(x))
# Out:
# <class 'tuple'> (321, 4162)
# 2

# %%
x = (321)
print(type(x), x)
# print(len(x))
# Out:
# <class 'int'> 321

# %%
x = (((((321)))))
print(type(x), x)
# Out:
# <class 'int'> 321

# %%
x = (321, )
print(type(x), x)
# Out:
# <class 'tuple'> (321,)

# %%
x = [321]
print(type(x), x)
# Out:
# <class 'list'> [321]

# %%
x = (321, )
print(type(x), x)
# Out:
# <class 'tuple'> (321,)

# %%
x = 321, 
print(type(x), x)
# Out:
# <class 'tuple'> (321,)

# %%
x = [321, ]
print(type(x), x)
# Out:
# <class 'list'> [321]

# %%
x = {321, 31, 4, 31, 312, 321}
print(type(x), x)
# Out:
# <class 'set'> {312, 321, 4, 31}

# %%
a = []
print(type(a))
# Out:
# <class 'list'>

# %%
a = []
print(bool(a))
# Out:
# False

# %%
text = "salutare"
print(text, type(text))
# Out:
# salutare <class 'str'>

# %%
text = "salutare"
text[0]
# Out:
# 's'

# %%
text = "salutare"
text[-1]
# Out:
# 'e'

# %% [markdown]
# # Stringul este imutabil

# %%
text = "salutare"
text[0] = "p"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 text = "salutare"
# ----> 2 text[0] = "p"
#
# TypeError: 'str' object does not support item assignment

# %%
text = "palutare"
print(text)
# Out:
# palutare

# %%
text = "salutare"
text.upper()
# Out:
# 'SALUTARE'

# %%
text
# Out:
# 'salutare'

# %%
text = "salutare"
new_text = text.upper()
print("new_text", new_text)
print("text", text)
# Out:
# new_text SALUTARE
# text salutare

# %%
range(10)
# Out:
# range(0, 10)

# %%
for i in range(10):
    print("i=", i)
# Out:
# i= 0
# i= 1
# i= 2
# i= 3
# i= 4
# i= 5
# i= 6
# i= 7
# i= 8
# i= 9

# %%
for i in range(10):
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(50, 60):
    print("i=", i)
# Out:
# i= 50
# i= 51
# i= 52
# i= 53
# i= 54
# i= 55
# i= 56
# i= 57
# i= 58
# i= 59

# %%
for i in range(50, 60, 3):
    print("i=", i)
# Out:
# i= 50
# i= 53
# i= 56
# i= 59

# %%
"#" * 10
# Out:
# '##########'

# %%
for i in range(10):
    print("#")
# Out:
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #

# %%
for i in range(10):
    print("#", end="")
# Out:
# ##########

# %%
for i in range(10):
    print("%", end="")
# Out:
# %%%%%%%%%%

# %%
for i in range(10):
    if i % 2 == 0:
        print("%", end="")
    else:
        print("-", end="")
# Out:
# %-%-%-%-%-

# %%
for i in range(100):
    if i % 2 == 0:
        print("%", end="")
    else:
        print("-", end="")
# Out:
# %-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-

# %%
for i in range(500, 600, 33):
    print("i=", i)
# Out:
# i= 500
# i= 533
# i= 566
# i= 599

# %%
for i in range(100, 50):
    print("i=", i)

# %%
for i in range(10, 1, -1):
    print("i=", i)
# Out:
# i= 10
# i= 9
# i= 8
# i= 7
# i= 6
# i= 5
# i= 4
# i= 3
# i= 2

# %%
list(range(10, 1, -1))
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %%
tuple(range(10, 1, -1))
# Out:
# (10, 9, 8, 7, 6, 5, 4, 3, 2)

# %%
text = "am o casuta mic asa si asa"
print(text, len(text))
# Out:
# am o casuta mic asa si asa 26

# %%
text = "am o casuta mic asa si asa"
print(text[0])
# Out:
# a

# %%
text = "am o casuta mic asa si asa"
print(text[0])
print(text[3])
# Out:
# a
# o

# %%
text = "am o casuta mic asa si asa"
print(text[0:3])
# Out:
# am

# %% [markdown]
# # Slice

# %%
text = "am o casuta mic asa si asa"
print(text[0:4])
# Out:
# am o

# %%
lista = [3, 41, 51, 1, 32, 51, 51, 412, 31]
print(lista[0:4])
# Out:
# [3, 41, 51, 1]

# %%
text = "am o casuta mic asa si ASa"
print(text[-3:-1])
# Out:
# AS

# %%
text = "am o casuta mic asa si ASa"
print(text[-3: ])
# Out:
# ASa

# %%
text = "am o casuta mic asa si asa"
print(text[0:4])
# Out:
# am o

# %%
text = "am o casuta mic asa si asa"
print(text[ :4])
# Out:
# am o

# %%
text = "am o casuta mic asa si asa"
print(text[ : ])
# Out:
# am o casuta mic asa si asa

# %%
text = "am o casuta mic asa si asa"
print(text[ : ])

# %%
lorem = "Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus beatae quam inventore suscipit obcaecati numquam, voluptas iste distinctio eos, labore aperiam quod animi, nulla id accusantium velit illum ducimus? Sed ipsa molestias recusandae ut atque unde odit ipsum excepturi cupiditate nam quod saepe, iusto eveniet, commodi iste voluptatum asperiores enim! Sequi nobis sunt ipsa, ipsam tenetur explicabo adipisci doloremque autem quas dolorem, cumque nesciunt repudiandae dicta id delectus, officia labore? Adipisci exercitationem cumque facere nulla cupiditate saepe ad alias omnis itaque, reiciendis optio velit voluptatem hic amet dolores eveniet nam fugiat? Pariatur quia asperiores, facere laboriosam alias dolore iure illum repudiandae nihil modi nam reiciendis blanditiis veritatis deleniti necessitatibus ducimus iste ullam odit perspiciatis in obcaecati, sint numquam minima expedita? Omnis enim labore porro cum culpa consequuntur nihil asperiores doloremque quam recusandae cumque impedit consequatur temporibus tenetur suscipit fugiat deserunt beatae dolorum, iure assumenda voluptatibus. Reiciendis explicabo reprehenderit laudantium est nisi non id quibusdam quae eius suscipit iure unde laborum ratione delectus, at temporibus iste? Dolores quaerat laudantium, est temporibus saepe sunt ducimus inventore porro odit nihil non quo, voluptas beatae delectus magni officia, provident fugit iusto eos voluptatem omnis eius dignissimos. Voluptatem, iure odio sit nisi, cumque doloremque possimus dolorum quia ipsa, quod cum dolores. Pariatur similique at, nihil totam obcaecati sapiente suscipit, tempora animi ullam beatae, magnam ipsam alias ab sint aliquam deserunt excepturi cupiditate iure fugiat? Rerum quis vel culpa distinctio expedita nam. Necessitatibus quam maxime ratione neque temporibus doloremque dolores tempore eveniet, nulla, hic consequatur labore molestias esse aut magnam explicabo minima veniam dolor odio tenetur incidunt id! Ratione impedit possimus sapiente culpa similique. Officia impedit iusto voluptates aperiam aspernatur facilis consequuntur aliquam magnam commodi exercitationem nobis nemo, doloribus ea esse possimus officiis laborum quidem."

# %%
lorem[0:20]
# Out:
# 'Lorem ipsum dolor si'

# %%
lorem[:20]
# Out:
# 'Lorem ipsum dolor si'

# %% [markdown]
# # Versiunea clasică (fără join)

# %%
cuvinte= lorem.split()
print(type(cuvinte), cuvinte)
# Out:
# <class 'list'> ['Lorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur', 'adipisicing', 'elit.', 'Deleniti', 'cum', 'dolorum', 'maxime', 'eos,', 'quidem', 'nihil', 'sed', 'id', 'assumenda.', 'Ex', 'natus', 'beatae', 'quam', 'inventore', 'suscipit', 'obcaecati', 'numquam,', 'voluptas', 'iste', 'distinctio', 'eos,', 'labore', 'aperiam', 'quod', 'animi,', 'nulla', 'id', 'accusantium', 'velit', 'illum', 'ducimus?', 'Sed', 'ipsa', 'molestias', 'recusandae', 'ut', 'atque', 'unde', 'odit', 'ipsum', 'excepturi', 'cupiditate', 'nam', 'quod', 'saepe,', 'iusto', 'eveniet,', 'commodi', 'iste', 'voluptatum', 'asperiores', 'enim!', 'Sequi', 'nobis', 'sunt', 'ipsa,', 'ipsam', 'tenetur', 'explicabo', 'adipisci', 'doloremque', 'autem', 'quas', 'dolorem,', 'cumque', 'nesciunt', 'repudiandae', 'dicta', 'id', 'delectus,', 'officia', 'labore?', 'Adipisci', 'exercitationem', 'cumque', 'facere', 'nulla', 'cupiditate', 'saepe', 'ad', 'alias', 'omnis', 'itaque,', 'reiciendis', 'optio', 'velit', 'voluptatem',
# ...

# %%
len(cuvinte)
# Out:
# 300

# %%
primele_20 = cuvinte[:20]
print(len(primele_20), type(primele_20), primele_20)
# Out:
# 20 <class 'list'> ['Lorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur', 'adipisicing', 'elit.', 'Deleniti', 'cum', 'dolorum', 'maxime', 'eos,', 'quidem', 'nihil', 'sed', 'id', 'assumenda.', 'Ex', 'natus']

# %%
cuvinte = ""

for cuv in primele_20:
    cuvinte += " " + cuv

cuvinte
# Out:
# ' Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
cuvinte.strip()
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
cuvinte
# Out:
# ' Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
cuvinte[1:]
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
cuvinte.lstrip()
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %% [markdown]
# # Versiunea scurta (frumoasa)

# %%
lorem = "Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus beatae quam inventore suscipit obcaecati numquam, voluptas iste distinctio eos, labore aperiam quod animi, nulla id accusantium velit illum ducimus? Sed ipsa molestias recusandae ut atque unde odit ipsum excepturi cupiditate nam quod saepe, iusto eveniet, commodi iste voluptatum asperiores enim! Sequi nobis sunt ipsa, ipsam tenetur explicabo adipisci doloremque autem quas dolorem, cumque nesciunt repudiandae dicta id delectus, officia labore? Adipisci exercitationem cumque facere nulla cupiditate saepe ad alias omnis itaque, reiciendis optio velit voluptatem hic amet dolores eveniet nam fugiat? Pariatur quia asperiores, facere laboriosam alias dolore iure illum repudiandae nihil modi nam reiciendis blanditiis veritatis deleniti necessitatibus ducimus iste ullam odit perspiciatis in obcaecati, sint numquam minima expedita? Omnis enim labore porro cum culpa consequuntur nihil asperiores doloremque quam recusandae cumque impedit consequatur temporibus tenetur suscipit fugiat deserunt beatae dolorum, iure assumenda voluptatibus. Reiciendis explicabo reprehenderit laudantium est nisi non id quibusdam quae eius suscipit iure unde laborum ratione delectus, at temporibus iste? Dolores quaerat laudantium, est temporibus saepe sunt ducimus inventore porro odit nihil non quo, voluptas beatae delectus magni officia, provident fugit iusto eos voluptatem omnis eius dignissimos. Voluptatem, iure odio sit nisi, cumque doloremque possimus dolorum quia ipsa, quod cum dolores. Pariatur similique at, nihil totam obcaecati sapiente suscipit, tempora animi ullam beatae, magnam ipsam alias ab sint aliquam deserunt excepturi cupiditate iure fugiat? Rerum quis vel culpa distinctio expedita nam. Necessitatibus quam maxime ratione neque temporibus doloremque dolores tempore eveniet, nulla, hic consequatur labore molestias esse aut magnam explicabo minima veniam dolor odio tenetur incidunt id! Ratione impedit possimus sapiente culpa similique. Officia impedit iusto voluptates aperiam aspernatur facilis consequuntur aliquam magnam commodi exercitationem nobis nemo, doloribus ea esse possimus officiis laborum quidem."

# %%
cuvinte = lorem.split()
primele = cuvinte[:20]

# %%
"hello".join(["2", "3", "4"])
# Out:
# '2hello3hello4'

# %%
"hello".join(["2", "3", "4", "5"])
# Out:
# '2hello3hello4hello5'

# %%
"-".join(primele)
# Out:
# 'Lorem-ipsum-dolor-sit-amet-consectetur-adipisicing-elit.-Deleniti-cum-dolorum-maxime-eos,-quidem-nihil-sed-id-assumenda.-Ex-natus'

# %%
" ".join(primele)
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
lorem = "Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus beatae quam inventore suscipit obcaecati numquam, voluptas iste distinctio eos, labore aperiam quod animi, nulla id accusantium velit illum ducimus? Sed ipsa molestias recusandae ut atque unde odit ipsum excepturi cupiditate nam quod saepe, iusto eveniet, commodi iste voluptatum asperiores enim! Sequi nobis sunt ipsa, ipsam tenetur explicabo adipisci doloremque autem quas dolorem, cumque nesciunt repudiandae dicta id delectus, officia labore? Adipisci exercitationem cumque facere nulla cupiditate saepe ad alias omnis itaque, reiciendis optio velit voluptatem hic amet dolores eveniet nam fugiat? Pariatur quia asperiores, facere laboriosam alias dolore iure illum repudiandae nihil modi nam reiciendis blanditiis veritatis deleniti necessitatibus ducimus iste ullam odit perspiciatis in obcaecati, sint numquam minima expedita? Omnis enim labore porro cum culpa consequuntur nihil asperiores doloremque quam recusandae cumque impedit consequatur temporibus tenetur suscipit fugiat deserunt beatae dolorum, iure assumenda voluptatibus. Reiciendis explicabo reprehenderit laudantium est nisi non id quibusdam quae eius suscipit iure unde laborum ratione delectus, at temporibus iste? Dolores quaerat laudantium, est temporibus saepe sunt ducimus inventore porro odit nihil non quo, voluptas beatae delectus magni officia, provident fugit iusto eos voluptatem omnis eius dignissimos. Voluptatem, iure odio sit nisi, cumque doloremque possimus dolorum quia ipsa, quod cum dolores. Pariatur similique at, nihil totam obcaecati sapiente suscipit, tempora animi ullam beatae, magnam ipsam alias ab sint aliquam deserunt excepturi cupiditate iure fugiat? Rerum quis vel culpa distinctio expedita nam. Necessitatibus quam maxime ratione neque temporibus doloremque dolores tempore eveniet, nulla, hic consequatur labore molestias esse aut magnam explicabo minima veniam dolor odio tenetur incidunt id! Ratione impedit possimus sapiente culpa similique. Officia impedit iusto voluptates aperiam aspernatur facilis consequuntur aliquam magnam commodi exercitationem nobis nemo, doloribus ea esse possimus officiis laborum quidem."

# %%
" ".join(lorem.split()[:20])
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Deleniti cum dolorum maxime eos, quidem nihil sed id assumenda. Ex natus'

# %%
text = "cine sapa groapa altuia"
text.replace("sapa", "face")
# Out:
# 'cine face groapa altuia'

# %%
text
# Out:
# 'cine sapa groapa altuia'

# %%
text = "cine sapa groapa altuia"
text.count("a")
# Out:
# 6

# %%
text = "cine sapa groapa altuia"
text.count("cine")
# Out:
# 1

# %%
text = "cine sapa groapa altuia"
text.count("cineva")
# Out:
# 0
