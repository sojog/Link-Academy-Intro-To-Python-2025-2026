# %%
print("good" == "great" or 67 != 76)
# Out:
# True

# %%
print("good" == "great") 
print(67 != 76)
# Out:
# False
# True

# %%
print(True and False) # False
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print("good" == "great" and 67 != 76)
# Out:
# False

# %%
x = "Hello"
print(bool(x))
# Out:
# True

# %%
x = ""
print(bool(x))
# Out:
# False

# %%
x = " "
print(bool(x))
# Out:
# True

# %%
x = "0"
print(bool(x))
# Out:
# True

# %%
x = 0
print(bool(x))
# Out:
# False

# %%
x = None
print(bool(x))
# Out:
# False

# %%
valoarea_introdusa = input("Introdu ceva")

if valoarea_introdusa:
    print("Ai introdus: ", valoarea_introdusa)
else:
    print("Nu ai introdus nimic")
# Out:
# Nu ai introdus nimic

# %%
valoarea_introdusa = input("Introdu ceva")

if bool(valoarea_introdusa):
    print("Ai introdus: ", valoarea_introdusa)
else:
    print("Nu ai introdus nimic")

# %%
name = ["robert"]
winner = ["robert"]
print(name == winner and name is winner)
# Out:
# False

# %%
name = ["robert"]
print(name, type(name))
# Out:
# ['robert'] <class 'list'>

# %%
v1 = "robert"
v2 = "robert"

print(v1 == v2)
# Out:
# True

# %% [markdown]
# # Bool, Int, Float, String  sunt primitive

# %%
v1 = "robert"
v2 = "robert"

print(v1 is v2)
# Out:
# True

# %%
name = "robert"
winner = "robert"
print(name == winner and name is winner)
# Out:
# True

# %%
name = ["robert"]
winner = ["robert"]
print(name == winner and name is winner)
# Out:
# False

# %%
name = ["robert"]
winner = ["robert"]
print(name == winner)
# Out:
# True

# %% [markdown]
# # Lista este un tip de date compus (din alte primitive)

# %%
name = ["robert"]
winner = ["robert"]
print(name is winner)
# Out:
# False
