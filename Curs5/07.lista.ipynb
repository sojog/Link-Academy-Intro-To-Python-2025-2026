# %%
lista = [21, 321, 41] 
len(lista)
# Out:
# 3

# %%
lista = [21, 321, 41] 
lista.append(390)
len(lista), lista
# Out:
# (4, [21, 321, 41, 390])

# %%
lista = [21, 321, 41] 
lista.append(390)
lista.append(390)
lista.append(390)
lista.append(390)
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 7
# lista: [21, 321, 41, 390, 390, 390, 390]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 7
# lista: [21, 321, 41, 52, 31, 5, 23]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
lista.pop()
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 6
# lista: [21, 321, 41, 52, 31, 5]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
lista.pop()
lista.pop()
lista.pop()
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 4
# lista: [21, 321, 41, 52]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
lista.pop(0)

print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 6
# lista: [321, 41, 52, 31, 5, 23]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
lista.pop(0)
lista.pop(0)
lista.pop(0)
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 4
# lista: [52, 31, 5, 23]

# %%
lista = [21, 321, 41, 52, 31, 5, 23] 
lista.clear()
print("lungimea liste:", len(lista))
print("lista:", lista)
# Out:
# lungimea liste: 0
# lista: []

# %%
lista = []

while True:
    nr = input("Introdu un numar")
    nr = int(nr)

    lista.append(nr)
    print("Lungimea liste", len(lista))
    print("componenta listei", lista)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 while True:
#       4     nr = input("Introdu un numar")
# ----> 5     nr = int(nr)
#       7     lista.append(nr)
#       8     print("Lungimea liste", len(lista))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
lista = []

nr = input("Introdu un numar")

while nr:    
    nr = int(nr)
    lista.append(nr)
    print("Lungimea liste", len(lista))
    print("componenta listei", lista)
    nr = input("Introdu un numar")
# Out:
# Lungimea liste 1
# componenta listei [312]
# Lungimea liste 2
# componenta listei [312, 12]
# Lungimea liste 3
# componenta listei [312, 12, 5]
# Lungimea liste 4
# componenta listei [312, 12, 5, 6]
# Lungimea liste 5
# componenta listei [312, 12, 5, 6, 1]

# %%
lista = [312, 12, 5, 6, 1]
print(lista)
# Out:
# [312, 12, 5, 6, 1]

# %%
lista[0]
# Out:
# 312

# %% [markdown]
# # for - bucla de iteratie

# %%
for i in lista:
    print("i=", i)
# Out:
# i= 312
# i= 12
# i= 5
# i= 6
# i= 1

# %%
for i in "telefon":
    print("i=", i)
# Out:
# i= t
# i= e
# i= l
# i= e
# i= f
# i= o
# i= n

# %%
lista = []

for i in range(5):  

    nr = input("Introdu un numar")
    nr = int(nr)

    lista.append(nr)

    print("Lungimea liste", len(lista))
    print("componenta listei", lista)
# Out:
# Lungimea liste 1
# componenta listei [11]
# Lungimea liste 2
# componenta listei [11, 22]
# Lungimea liste 3
# componenta listei [11, 22, 33]
# Lungimea liste 4
# componenta listei [11, 22, 33, 44]
# Lungimea liste 5
# componenta listei [11, 22, 33, 44, 55]

# %%
lista = [312, 12, 5, 6, 1]
lista.sort()
print(lista)
# Out:
# [1, 5, 6, 12, 312]

# %%
lista = [312, 12, 205, 61, 1]
lista.sort(reverse = True)
print(lista)
# Out:
# [312, 205, 61, 12, 1]

# %%
lista = [312, 12, 205, 61, 1]
lista.sort(reverse = False)
print(lista)
# Out:
# [1, 12, 61, 205, 312]
