# %%
1st_var = 'hello'
print(1st_var)
# Out:
#   Cell In[1], line 1
#     1st_var = 'hello'
#     ^
# SyntaxError: invalid decimal literal

# %%
f1st_var = 'hello'
print(f1st_var)
# Out:
# hello

# %%
### pass este folosit ca un keyword
pass = 'hello'
print(pass)
# Out:
#   Cell In[4], line 2
#     pass = 'hello'
#          ^
# SyntaxError: invalid syntax

# %%
## Python este case sensitive
greeting = 'hello'
print(Greeting)
Greeting = 'How are you'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 greeting = 'hello'
# ----> 2 print(Greeting)
#       3 Greeting = 'How are you'
#
# NameError: name 'Greeting' is not defined

# %%
greeting = 'hello'
Greeting = 'How are you'
print(Greeting)
# Out:
# How are you

# %%
print(Greeting)
# Out:
# How are you

# %%
print(greeting)
# Out:
# hello

# %% [markdown]
# # True este o valoare booleana

# %%
has_greeted = True
print(has_greeted, type(has_greeted))
# Out:
# True <class 'bool'>

# %%
has_greeted = "true"
print(has_greeted, type(has_greeted))
# Out:
# true <class 'str'>

# %% [markdown]
# # true poate fi numele unei variabile

# %%
true = 200

has_greeted = true
print(has_greeted, type(has_greeted))
# Out:
# 200 <class 'int'>

# %%
has_greeted = false
print(has_greeted, type(has_greeted))

# %%
print (9//2)
# Out:
# 4

# %%
print (9/2)
# Out:
# 4.5

# %%
print (9/3)
# Out:
# 3.0

# %%
print (9//3)
# Out:
# 3

# %%
print (9*"2")
# Out:
# 222222222

# %% [markdown]
# # Concatenare (alipirea a 2 stringuri)

# %%
print ("2" + "2")
# Out:
# 22

# %%
print (3*"2")
print ("2" + "2" + "2")
# Out:
# 222
# 222

# %% [markdown]
# # Inmultirea unui string cu float nu este posibila

# %%
print ("2"*9.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print ("2"*9.0)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print ("2" *  9.1)

# %%
print ("2" *  int(9.1))
# Out:
# 222222222

# %%
x = 321.31241341
print(int(x))
# Out:
# 321

# %%
print (int("2") *  9.2)
# Out:
# 18.4

# %%
x = "312312"
print(x, type(x))
# Out:
# 312312 <class 'str'>

# %%
x = 312312
print(x, type(x))
# Out:
# 312312 <class 'int'>

# %%
x = "312312"
x = int(x)

print(x, type(x))
# Out:
# 312312 <class 'int'>

# %%
x = "312312@"
x = int(x)

print(x, type(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 x = "312312@"
# ----> 2 x = int(x)
#       4 print(x, type(x))
#
# ValueError: invalid literal for int() with base 10: '312312@'

# %% [markdown]
# ## Nu are sens

# %%
print ("2"*"9")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print ("2"*"9")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print (9+"2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 print (9+"2")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(9 + "2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(9 + "2")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Concatenare

# %%
print(str(9) + "2")
# Out:
# 92

# %% [markdown]
# # Adunare

# %%
print(9 + int("2"))
# Out:
# 11

# %%
print(9 + float("2"))
# Out:
# 11.0

# %% [markdown]
# # Int si float sunt compatibile 100%

# %%
23 + 10.0
# Out:
# 33.0

# %%
10/2
# Out:
# 5.0

# %%
3 * 2.0
# Out:
# 6.0

# %%
int(31312.0412)
# Out:
# 31312

# %%
float(23)
# Out:
# 23.0

# %%
x = "312.0"
print(x, type(x))
# Out:
# 312.0 <class 'str'>

# %%
x = "312.0"
x = float(x)
print(x, type(x))
# Out:
# 312.0 <class 'float'>

# %%
x = "312.0"
x = int(float(x))
print(x, type(x))
# Out:
# 312 <class 'int'>

# %%
print (9 ** 2)
# Out:
# 81

# %%
print (81 ** (0.5))
# Out:
# 9.0

# %%
print (81 ** (1/2))
# Out:
# 9.0

# %% [markdown]
# # Python urmeaza principiile matematice

# %%
print (2*1**2)
# Out:
# 2

# %%
print (2 * (1**2) )
# Out:
# 2

# %%
print ('a'+'b' * 2 + 4 * 'a' )
# Out:
# abbaaaa

# %% [markdown]
# # Operatorul * are precedență față de operatorul +

# %%
print ('a'+'bb' + 'aaaa' )
# Out:
# abbaaaa
