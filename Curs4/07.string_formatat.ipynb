# %%
suma = 10
print("Suma este:" +  suma )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 suma = 10
# ----> 2 print("Suma este:" +  suma )
#
# TypeError: can only concatenate str (not "int") to str

# %%
suma = 10
print("Suma este:" +  str(suma))
# Out:
# Suma este:10

# %%
suma = 10
print("Suma este:", suma)
# Out:
# Suma este: 10

# %%
print("alb", "negru", "rosu", "verde" )
# Out:
# alb negru rosu verde

# %%
print("alb" +  "negru" + "rosu" + "verde" )
# Out:
# albnegrurosuverde

# %%
suma = 10
text = f"Suma este: {suma}"
print(text)
# Out:
# Suma este: 10
